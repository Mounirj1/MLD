# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading data

# %%
data = pd.read_csv('../input/breast-cancer-wisconsin.csv');

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### Correlaton Matrix

# %%
feature_list_1= list(data.columns[1:10])
plt.figure(figsize=(10,10))
sns.heatmap(data[feature_list_1].corr(), annot=True, square=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
color_dic = {'M':'red', 'B':'green'}
colors = data['diagnosis'].map(lambda x: color_dic.get(x))
sm = pd.plotting.scatter_matrix(data[feature_list_1], c=colors, alpha=0.4, figsize=((15,15)));
plt.show()

# %% [markdown]
# ### Box Plot

# %%
plt.figure(figsize=(15,15))
for i, feature in enumerate(feature_list_1[1:]):
    rows = int(len(feature_list_1)/2)
    plt.subplot(rows, 2, i+1)
    sns.boxplot(x='diagnosis', y=feature, data=data, palette="Set2")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlaton Matrix

# %%
feature_list_2= list(data.columns[11:20])
plt.figure(figsize=(10,10))
sns.heatmap(data[feature_list_1].corr(), annot=True, square=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
color_dic = {'M':'red', 'B':'green'}
colors = data['diagnosis'].map(lambda x: color_dic.get(x))
sm = pd.plotting.scatter_matrix(data[feature_list_2], c=colors, alpha=0.4, figsize=((15,15)));
plt.show()

# %% [markdown]
# ### Box Plot

# %%
plt.figure(figsize=(15,15))
for i, feature in enumerate(feature_list_2[1:]):
    rows = int(len(feature_list_2)/2)
    plt.subplot(rows, 2, i+1)
    sns.boxplot(x='diagnosis', y=feature, data=data, palette="Set2")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlaton Matrix

# %%
feature_list_3= list(data.columns[21:30])
plt.figure(figsize=(10,10))
sns.heatmap(data[feature_list_1].corr(), annot=True, square=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
color_dic = {'M':'red', 'B':'green'}
colors = data['diagnosis'].map(lambda x: color_dic.get(x))
sm = pd.plotting.scatter_matrix(data[feature_list_3], c=colors, alpha=0.4, figsize=((15,15)));
plt.show()

# %% [markdown]
# ### Box Plot

# %%
plt.figure(figsize=(15,15))
for i, feature in enumerate(feature_list_3[1:]):
    rows = int(len(feature_list_3)/2)
    plt.subplot(rows, 2, i+1)
    sns.boxplot(x='diagnosis', y=feature, data=data, palette="Set2")

plt.tight_layout()
plt.show()
